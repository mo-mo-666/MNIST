# %% [markdown]
# # t-SNE による次元削減

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

seaborn.set()
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %% [markdown]
# ### データの読み込み

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('MNIST_784')

datas = mnist.data[:10000]
labels = np.array(list(map(int, mnist.target[:10000])))

# %% [markdown]
# ### 学習と図示

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2,
            perplexity=30, 
            learning_rate=200, 
            random_state=0,
            n_iter=250,
            n_jobs=-1)

# %%
# %%time
coords = tsne.fit_transform(datas)
# Out:
# CPU times: user 5min 8s, sys: 216 ms, total: 5min 9s
# Wall time: 2min 36s

# %%
plt.figure(figsize=(10, 10))
for i in range(10):
    c = coords[labels==i]
    plt.scatter(c[:, 0], c[:, 1], alpha=0.5, label=i)
plt.legend()
plt.show()
